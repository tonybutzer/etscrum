# %%
file = open("taken.csv", 'r') 
#print (file.read() )

# %%
a = file.read()

b=a.split()

c=[]
for i in b:
    print(i)
    if 'TAKEN' in i:
        c.append(i)
# Out:
# KELLOGG
# BROWN
# &
# ROOT
# LLCLeave
# ReportDate/Time:Nov
# 4,
# 2020
# 3:06
# PMPrinted
# By:Butzer,
# Tony
# (10028516)Deltek
# Time
# Version:9.0.1.0Number
# of
# Pages:2Report
# Options:Leave
# Type:PTOEmployee
# Name:Butzer,
# Tony
# (10028516)
# KELLOGG
# BROWN
# &
# ROOT
# LLCLeave
# ReportPage1of2Nov
# 4,
# 20203:06
# PMDateTypeHoursReasonDec
# 29,
# 2019BEG365.08Jan
# 2,
# 2020TAKEN-1.00Jan
# 4,
# 2020ACCRUED3.85Jan
# 11,
# 2020ACCRUED3.85Jan
# 18,
# 2020ACCRUED3.85Jan
# 25,
# 2020ACCRUED3.85Jan
# 27,
# 2020TAKEN0.00Jan
# 28,
# 2020TAKEN-2.00Jan
# 29,
# 2020TAKEN-2.00Jan
# 30,
# 2020TAKEN-2.00Jan
# 31,
# 2020TAKEN-2.00Feb
# 1,
# 2020ACCRUED3.85Feb
# 8,
# 2020ACCRUED3.85Feb
# 15,
# 2020ACCRUED3.85Feb
# 22,
# 2020ACCRUED3.85Feb
# 29,
# 2020ACCRUED3.85Mar
# 7,
# 2020ACCRUED3.85Mar
# 14,
# 2020ACCRUED3.85Mar
# 21,
# 2020ACCRUED3.85Mar
# 26,
# 2020ADJUSTMENT-164.00TSSC
# EA
# PayoutMar
# 28,
# 2020ACCRUED3.85Apr
# 4,
# 2020ACCRUED3.85Apr
# 11,
# 2020ACCRUED3.85Apr
# 18,
# ...

# %%
c
# Out:
# ['2020TAKEN-1.00Jan',
#  '2020TAKEN0.00Jan',
#  '2020TAKEN-2.00Jan',
#  '2020TAKEN-2.00Jan',
#  '2020TAKEN-2.00Jan',
#  '2020TAKEN-2.00Feb',
#  '2020TAKEN-8.00Jun',
#  '2020TAKEN-6.00Jun',
#  '2020TAKEN-8.00Jun',
#  '2020TAKEN-6.00Jun',
#  '2020TAKEN-8.00Jul',
#  '2020TAKEN-4.00Jul',
#  '2020TAKEN-8.00Jul',
#  '2020TAKEN-4.00Aug',
#  '2020TAKEN-8.00Aug',
#  '2020TAKEN-4.00Aug',
#  '2020TAKEN-8.00Aug',
#  '2020TAKEN-4.00Aug',
#  '2020TAKEN-8.00Aug',
#  '2020TAKEN-4.00Aug',
#  '2020TAKEN-8.00Aug',
#  '2020TAKEN-8.00Aug',
#  '2020TAKEN-8.00Sep',
#  '2020TAKEN-2.00Oct']

# %%
sum=0
for h in c:
    print(h)
    if '-' in h:
        k=h.split('-')[1]
        t=k.split('.')[0]
        print (t)
        sum = sum + int(t)
sum
# Out:
# 2020TAKEN-1.00Jan
# 1
# 2020TAKEN0.00Jan
# 2020TAKEN-2.00Jan
# 2
# 2020TAKEN-2.00Jan
# 2
# 2020TAKEN-2.00Jan
# 2
# 2020TAKEN-2.00Feb
# 2
# 2020TAKEN-8.00Jun
# 8
# 2020TAKEN-6.00Jun
# 6
# 2020TAKEN-8.00Jun
# 8
# 2020TAKEN-6.00Jun
# 6
# 2020TAKEN-8.00Jul
# 8
# 2020TAKEN-4.00Jul
# 4
# 2020TAKEN-8.00Jul
# 8
# 2020TAKEN-4.00Aug
# 4
# 2020TAKEN-8.00Aug
# 8
# 2020TAKEN-4.00Aug
# 4
# 2020TAKEN-8.00Aug
# 8
# 2020TAKEN-4.00Aug
# 4
# 2020TAKEN-8.00Aug
# 8
# 2020TAKEN-4.00Aug
# 4
# 2020TAKEN-8.00Aug
# 8
# 2020TAKEN-8.00Aug
# 8
# 2020TAKEN-8.00Sep
# 8
# 2020TAKEN-2.00Oct
# 2
# 123
