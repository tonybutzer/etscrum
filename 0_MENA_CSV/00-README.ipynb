# %% [markdown]
# # MENA - Middle East ? ?
#
# # Gaza Strip Basin
#
# # srf, eta,

# %% [markdown]
# # Start with srf
#
# ## Tasks/Todo
#
# 1. wrangle srf daily into dev-et-data
# 2. find prior art examples
# 3. unit test these
# 4. start to integrate and test the integrations of these code snippits
#
# 5. make a panel app in jupyter
# 6. deploy a panel app on tendaollar machine as proof of concept
# 7. hand off r&d code to code owner python

# %%
! aws s3 ls dev-et-data/datalake/mena/srf_daily_mm/1984/
# Out:
# 2021-05-19 18:48:39         81 srf_1984001.tfw
# 2021-05-19 18:48:40    5312222 srf_1984001.tif
# 2021-05-19 18:48:39       1337 srf_1984001.tif.aux.xml
# 2021-05-19 18:48:40     257245 srf_1984001.tif.ovr
# 2021-05-19 18:48:40         81 srf_1984002.tfw
# 2021-05-19 18:48:40    5310320 srf_1984002.tif
# 2021-05-19 18:48:40       1324 srf_1984002.tif.aux.xml
# 2021-05-19 18:48:40         81 srf_1984003.tfw
# 2021-05-19 18:48:40    5310322 srf_1984003.tif
# 2021-05-19 18:48:40       1240 srf_1984003.tif.aux.xml
# 2021-05-19 18:48:40         81 srf_1984004.tfw
# 2021-05-19 18:48:40    5310322 srf_1984004.tif
# 2021-05-19 18:48:40       1190 srf_1984004.tif.aux.xml
# 2021-05-19 18:48:40         81 srf_1984005.tfw
# 2021-05-19 18:48:40    5310322 srf_1984005.tif
# 2021-05-19 18:48:40       1114 srf_1984005.tif.aux.xml
# 2021-05-19 18:48:40         81 srf_1984006.tfw
# 2021-05-19 18:48:40    5310320 srf_1984006.tif
# 2021-05-19 18:48:40       1096 srf_1984006.tif.aux.xml
# ...

# %% [markdown]
# # AOI VIZ Tool for MENA srf etc

# %% [markdown]
# 1. create a fakelib setup
# 2. what functions do we have?
#     - create a csv from a timeseries
#     - create an xarray from daily tifs
#         - pickle the xarray or save as a netcdf - for speed
#     - point picker x,y or enter lat long in text boxes
