# %%
! conda list
# Out:
# # packages in environment at /home/butzer/miniconda3/envs/pangeo:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       1_gnu    conda-forge
# affine                    2.3.0                      py_0    conda-forge
# aiobotocore               1.2.2              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.7.4            py39h3811e60_0    conda-forge
# aioitertools              0.7.1              pyhd8ed1ab_0    conda-forge
# anyio                     2.2.0            py39hf3d152e_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# argon2-cffi               20.1.0           py39hbd71b63_2    conda-forge
# asciitree                 0.3.3                      py_2    conda-forge
# async-timeout             3.0.1                   py_1000    conda-forge
# ...

# %%
! ls /caldera/projects/usgs/water/impd/butzer
# Out:
# nlcd_anhb_1985_mos_v1_cog.tif  nlcd_anhb_2002_mos_v1_cog.tif
# nlcd_anhb_1986_mos_v1_cog.tif  nlcd_anhb_2003_mos_v1_cog.tif
# nlcd_anhb_1987_mos_v1_cog.tif  nlcd_anhb_2004_mos_v1_cog.tif
# nlcd_anhb_1988_mos_v1_cog.tif  nlcd_anhb_2005_mos_v1_cog.tif
# nlcd_anhb_1989_mos_v1_cog.tif  nlcd_anhb_2006_mos_v1_cog.tif
# nlcd_anhb_1990_mos_v1_cog.tif  nlcd_anhb_2007_mos_v1_cog.tif
# nlcd_anhb_1991_mos_v1_cog.tif  nlcd_anhb_2008_mos_v1_cog.tif
# nlcd_anhb_1992_mos_v1_cog.tif  nlcd_anhb_2009_mos_v1_cog.tif
# nlcd_anhb_1993_mos_v1_cog.tif  nlcd_anhb_2010_mos_v1_cog.tif
# nlcd_anhb_1994_mos_v1_cog.tif  nlcd_anhb_2011_mos_v1_cog.tif
# nlcd_anhb_1995_mos_v1_cog.tif  nlcd_anhb_2013_mos_v1_cog.tif
# nlcd_anhb_1996_mos_v1_cog.tif  nlcd_anhb_2014_mos_v1_cog.tif
# nlcd_anhb_1997_mos_v1_cog.tif  nlcd_anhb_2015_mos_v1_cog.tif
# nlcd_anhb_1998_mos_v1_cog.tif  nlcd_anhb_2016_mos_v1_cog.tif
# nlcd_anhb_1999_mos_v1_cog.tif  nlcd_anhb_2017_mos_v1_cog.tif
# ...

# %%
from fsspec.implementations.local import LocalFileSystem
path='/caldera/projects/usgs/water/impd/butzer'

fs=LocalFileSystem()

# %%
my_tifs = fs.ls(path)

# %%
my_tifs
# Out:
# ['/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2008_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_1987_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_1993_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2010_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2017_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2001_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2006_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_1992_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_1991_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2016_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2014_mos_v1_cog.tif',
#  '/caldera/projects/usgs/water/impd/butzer/nlcd_anhb_2004_mos_v1_cog.tif',
# ...
