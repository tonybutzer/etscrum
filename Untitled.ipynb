# %% [markdown]
# --:--
#
#
#
# Machine Automated
#
# MAGIC
#
# AWS env setup
#
# Fuse datasets into a sensor agnostic datacube
#
# datacube structire
# data conditioning
#
# nasa c
#
# gdal
#
# ogr vector
#
# gdal cube structure
#
# R based STARS
#
#
#
#
#
#
# Leave
# Patrick McBride - ASTRA, LLC (Guest)
# +9
# Profile picture of Sam Sipe (Guest).
# Profile picture of 9b803636-f13f-48fe-a28f-8f293061005b.
# Zachary Boak (Contractor)
# Profile picture of Barber, Christopher P.
# Barber, Christopher P
# Kristy F Tiampo
# Profile picture of Chance (APL) (Guest).
# Chance (APL) (Guest)
# Profile picture of Butzer, Tony (Contractor).
# Participants
#
#
# Invite someone or dial a number
#
# Share invite
# In this meeting (16)
#
# Mute all
# Profile picture of Butzer, Tony (Contractor).
# Butzer, Tony (Contractor)
#
# Has context menu
# Has context menu
# Profile picture of +17*******28.
# +17*******28
# Has context menu
# Has context menu
# Profile picture of Amit Banerjee.
# Amit Banerjee
# Outside your organization
# Has context menu
# Has context menu
# Profile picture of Barber, Christopher P.
# Barber, Christopher P
# Has context menu
# Has context menu
# Profile picture of Chance (APL) (Guest).
# Chance (APL) (Guest)
# Has context menu
# Has context menu
# Profile picture of Jack Ziegler (Guest).
# Jack Ziegler (Guest)
# Has context menu
# Has context menu
# Profile picture of Joseph McGlinchy.
# Joseph McGlinchy
# Outside your organization
# Has context menu
# Has context menu
# Profile picture of Kristy F Tiampo.
# Kristy F Tiampo
# Outside your organization
# Has context menu
# Has context menu
# Profile picture of Levy, Blake (Airin) (Guest).
# Levy, Blake (Airin) (Guest)
# Has context menu
# Has context menu
# Profile picture of Mark V Giglio.
# Mark V Giglio
# Outside your organization
# Has context menu
# Has context menu
# Profile picture of Michael John Willis.
# Michael John Willis
# Outside your organization
# Has context menu
# Has context menu
# Profile picture of Mierau, Dean A.
# Mierau, Dean A
# Has context menu
# Has context menu
# Profile picture of Patrick McBride - ASTRA, LLC (Guest).
# Patrick McBride - ASTRA, LLC (Guest)
# Has context menu
# Has context menu
# Profile picture of Sam Sipe (Guest).
# Sam Sipe (Guest)
# Has context menu
# Has context menu
# Profile picture of Smith, Kelcy (Contractor) L.
# Smith, Kelcy (Contractor) L
# Has context menu
# Has context menu
# Profile picture of Zachary Boak (Contractor).
# Zachary Boak (Contractor)
# Outside your organization
# Has context menu
# Has context menu
# Others invited (1)
# Profile picture of Jack Cooper (Government).
# Jack Cooper (Government)
# No response
# Has context menu
# Others from chat (2)
# Profile picture of Sam Sipe (Contractor).
# Sam Sipe (Contractor)
# Has context menu
# Profile picture of Gregory Mitchell (Contractor).
# Gregory Mitchell (Contractor)
# Has context menu
# Kristy F Tiampo joined the call
